# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ### ACS sampling - BERT Xiao NER - 2% steps

# %%
# Accumulated results from "\al-nlp-req\NER_from_scratch\AL_inference_evalrun"

# starting model:   bert-base-cased
# dataset:          dxiao/requirements-ner
# query strategy:   ACS ranking
# training time:    ?
# training setup:   10% steps to 600 examples
#                   Num Epochs = 3
#                   Instantaneous batch size per device = 8
#                   Total train batch size (w. parallel, distributed & accumulation) = 8
#                   Gradient Accumulation steps = 1

# shuffled (seed 42)
score_f1_ACS = [0,0.011,0.000,0.131,0.389,0.577,0.646,0.672,0.715,0.742,0.776,0.802,0.826,0.860,0.881,0.888,0.891,0.888,0.887,0.883,0.888,0.894,0.898,0.896,0.895,0.893,0.893,0.891,0.892,0.894,0.898,0.898,0.893,0.896,0.897,0.892,0.884,0.882,0.885,0.877,0.882,0.883,0.884,0.883,0.879,0.881,0.883,0.888,0.877,0.887,0.880]
score_accuracy_ACS = [0,0.463,0.475,0.531,0.683,0.787,0.843,0.870,0.892,0.912,0.922,0.925,0.931,0.934,0.939,0.943,0.944,0.944,0.943,0.941,0.943,0.946,0.947,0.947,0.944,0.946,0.946,0.945,0.945,0.946,0.947,0.947,0.945,0.946,0.946,0.947,0.943,0.943,0.940,0.938,0.939,0.940,0.941,0.941,0.939,0.939,0.940,0.942,0.938,0.944,0.942]


# score_f1_ACS = [0,0.002,0.000,0.192,0.472,0.656,0.760,0.783,0.813,0.823,0.845,0.846,0.866,0.879,0.883,0.881,0.883,0.892,0.890,0.888,0.886,0.880,0.888,0.886,0.883,0.888,0.887,0.887,0.888,0.893,0.888,0.881,0.883,0.891,0.890,0.891,0.892,0.894,0.894,0.895,0.893,0.898,0.896,0.890,0.893,0.893,0.891,0.888,0.889,0.886,0.884]
# score_accuracy_ACS = [0,0.438,0.475,0.604,0.725,0.827,0.874,0.904,0.908,0.926,0.930,0.930,0.938,0.940,0.943,0.943,0.943,0.943,0.943,0.943,0.939,0.939,0.941,0.939,0.938,0.941,0.938,0.940,0.941,0.943,0.940,0.938,0.939,0.941,0.942,0.944,0.944,0.946,0.949,0.943,0.949,0.949,0.946,0.948,0.948,0.946,0.945,0.946,0.946,0.943,0.943]


# shuffled (seed 42)
score_f1_RS = [0,0.000,0.000,0.104,0.472,0.702,0.738,0.773,0.790,0.819,0.835,0.834,0.846,0.848,0.851,0.854,0.862,0.863,0.866,0.873,0.881,0.893,0.885,0.895,0.892,0.890,0.884,0.886,0.878,0.888,0.886,0.874,0.865,0.870,0.875,0.869,0.869,0.880,0.871,0.870,0.871,0.872,0.868,0.868,0.871,0.869,0.872,0.871,0.870,0.869,0.866]
score_accuracy_RS  = [0,0.463,0.475,0.582,0.740,0.827,0.867,0.906,0.908,0.924,0.927,0.930,0.932,0.931,0.933,0.936,0.938,0.938,0.936,0.943,0.942,0.944,0.943,0.945,0.944,0.942,0.942,0.940,0.941,0.941,0.940,0.939,0.937,0.936,0.935,0.932,0.930,0.935,0.933,0.932,0.931,0.931,0.931,0.931,0.931,0.932,0.929,0.931,0.930,0.930,0.930]

# score_f1_RS = [0,0.000,0.000,0.103,0.489,0.695,0.762,0.765,0.809,0.811,0.826,0.833,0.844,0.844,0.868,0.866,0.871,0.857,0.849,0.854,0.863,0.848,0.858,0.860,0.855,0.863,0.858,0.858,0.862,0.862,0.866,0.854,0.865,0.862,0.859,0.863,0.864,0.865,0.875,0.864,0.860,0.856,0.865,0.864,0.864,0.868,0.874,0.864,0.875,0.865,0.870]
# score_accuracy_RS  = [0,0.474,0.476,0.571,0.745,0.825,0.865,0.889,0.913,0.914,0.920,0.920,0.922,0.923,0.932,0.932,0.934,0.927,0.928,0.929,0.931,0.926,0.928,0.929,0.928,0.935,0.934,0.929,0.925,0.930,0.931,0.927,0.929,0.929,0.930,0.932,0.929,0.927,0.931,0.930,0.930,0.931,0.932,0.930,0.930,0.932,0.933,0.930,0.934,0.938,0.936]

score_f1_EN = [0, 0.002, 0.0, 0.01, 0.375, 0.598, 0.716, 0.73, 0.748, 0.774, 0.812, 0.835, 0.834, 0.839, 0.854, 0.857, 0.853, 0.867, 0.88, 0.874, 0.875, 0.868, 0.869, 0.867, 0.872, 0.87, 0.869, 0.866, 0.867, 0.866, 0.877, 0.868, 0.87, 0.873, 0.879, 0.883, 0.878, 0.887, 0.878, 0.879, 0.879, 0.872, 0.876, 0.87, 0.877, 0.874, 0.858, 0.873, 0.875, 0.865, 0.873]

steps_absolute = list(np.linspace(0, 600, 50+1))
steps_relative = list(x/6 for x in steps_absolute)

plt.plot(steps_relative, score_f1_ACS, label='least confidence')
plt.plot(steps_relative, score_f1_RS, label='random sampling', linestyle = '--', color = 'lightcoral')
plt.plot(steps_relative, score_f1_EN, label='entropy', linestyle = '-.', color = 'lightgreen')

ymax = max(max(score_f1_ACS),max(score_f1_RS),max(score_f1_EN))
plt.axhline(y=ymax, color='orange', label='no AL')
plt.xlim([0, 100])
plt.ylim([0, 1])
plt.title("BERT based on xiao NER 2% steps")
plt.xlabel('Percentage of manually labeled data')
plt.xticks(list(np.linspace(0, 100, 11)))
plt.ylabel('F1 score')
plt.yticks(list(np.linspace(0, 1, 11)))
plt.legend(loc='lower right')
plt.grid(color='grey', linewidth=0.2)
# plt.ylabel('Accuracy score')
plt.show()

# %%
len(score_f1_ACS)
# Out:
# 51

# %% [markdown]
# ### ACS sampling - BERT Xiao NER - 5% steps

# %%
# Accumulated results from "\al-nlp-req\NER_from_scratch\AL_inference_evalrun"

# starting model:   bert-base-cased
# dataset:          dxiao/requirements-ner
# query strategy:   ACS ranking
# training time:    ?
# training setup:   10% steps to 600 examples
#                   Num Epochs = 3
#                   Instantaneous batch size per device = 8
#                   Total train batch size (w. parallel, distributed & accumulation) = 8
#                   Gradient Accumulation steps = 1


# shuffled (seed 42)
score_f1_ACS = [0,0.000,0.182,0.640,0.791,0.810,0.857,0.886,0.885,0.892,0.891,0.887,0.897,0.891,0.895,0.898,0.901,0.899,0.902,0.890,0.890]
score_accuracy_ACS = [0,0.475,0.621,0.810,0.890,0.919,0.935,0.941,0.943,0.942,0.945,0.941,0.945,0.944,0.943,0.946,0.946,0.946,0.946,0.945,0.942]

# score_f1_ACS = [0,0.000,0.239,0.709,0.777,0.819,0.851,0.875,0.874,0.877,0.881,0.887,0.889,0.889,0.892,0.893,0.902,0.896,0.896,0.897,0.895]
# score_accuracy_ACS = [0,0.476,0.629,0.812,0.884,0.915,0.935,0.939,0.939,0.940,0.941,0.942,0.946,0.946,0.947,0.948,0.948,0.949,0.948,0.950,0.948]

# shuffled (seed 42)
score_f1_RS =[0,0.000,0.143,0.675,0.782,0.811,0.839,0.860,0.869,0.875,0.879,0.879,0.885,0.884,0.884,0.889,0.888,0.890,0.893,0.894,0.892]
score_accuracy_RS = [0,0.475,0.627,0.820,0.891,0.921,0.932,0.939,0.937,0.940,0.942,0.943,0.945,0.945,0.947,0.944,0.943,0.943,0.945,0.944,0.943]

# score_f1_RS = [0,0.000,0.169,0.656,0.773,0.817,0.848,0.855,0.865,0.862,0.871,0.861,0.868,0.865,0.862,0.885,0.866,0.879,0.890,0.884,0.871]
# score_accuracy_RS  = [0,0.475,0.611,0.810,0.891,0.920,0.927,0.927,0.934,0.931,0.938,0.932,0.933,0.934,0.931,0.939,0.935,0.938,0.941,0.936,0.935]

score_f1_EN = [0, 0.0, 0.128, 0.656, 0.765, 0.816, 0.845, 0.854, 0.86, 0.868, 0.89, 0.878, 0.886, 0.887, 0.89, 0.88, 0.88, 0.888, 0.887, 0.878, 0.881]

steps_absolute = list(np.linspace(0, 600, 20+1))
steps_relative = list(x/6 for x in steps_absolute)

plt.plot(steps_relative, score_f1_ACS, label='least confidence')
plt.plot(steps_relative, score_f1_RS, label='random sampling', linestyle = '--', color = 'lightcoral')
plt.plot(steps_relative, score_f1_EN, label='entropy', linestyle = '-.', color = 'lightgreen')

ymax = max(max(score_f1_ACS),max(score_f1_RS),max(score_f1_EN))
plt.axhline(y=ymax, color='orange', label='no AL')
plt.xlim([0, 100])
plt.ylim([0, 1])
plt.title("BERT based on xiao NER 5% steps")
plt.xlabel('Percentage of manually labeled data')
plt.xticks(list(np.linspace(0, 100, 11)))
plt.ylabel('F1 score')
plt.yticks(list(np.linspace(0, 1, 11)))
plt.legend(loc='lower right')
plt.grid(color='grey', linewidth=0.2)
# plt.ylabel('Accuracy score')
plt.show()

# %% [markdown]
# ### ACS sampling - BERT Xiao NER - 10% steps

# %%
# Accumulated results from "\al-nlp-req\NER_from_scratch\AL_inference_evalrun"

# starting model:   bert-base-cased
# dataset:          dxiao/requirements-ner
# query strategy:   ACS ranking
# training time:    ?
# training setup:   10% steps to 600 examples
#                   Num Epochs = 3
#                   Instantaneous batch size per device = 8
#                   Total train batch size (w. parallel, distributed & accumulation) = 8
#                   Gradient Accumulation steps = 1

# shuffled (seed 42)
score_f1_ACS = [0,0.000,0.681,0.784,0.856,0.886,0.891,0.896,0.893,0.887,0.888]
score_accuracy_ACS = [0,0.496,0.836,0.894,0.934,0.943,0.945,0.945,0.944,0.942,0.944]

# score_f1_ACS = [0,0.000,0.641,0.814,0.853,0.880,0.885,0.891,0.890,0.893,0.895]
# score_accuracy_ACS = [0,0.479,0.818,0.913,0.937,0.941,0.943,0.945,0.945,0.945,0.945]

# shuffled (seed 42)
score_f1_RS = [0, 0.000, 0.689, 0.784, 0.834, 0.866, 0.897, 0.894, 0.893, 0.889, 0.892]
score_accuracy_RS = [0,0.480,0.817,0.908,0.932,0.941,0.946,0.946,0.946,0.945,0.945]

# score_f1_RS = [0,0.000,0.668,0.803,0.842,0.860,0.882,0.872,0.872,0.898,0.886]
# score_accuracy_RS = [0,0.487,0.807,0.910,0.929,0.933,0.932,0.933,0.933,0.940,0.939]

score_f1_EN = [0, 0.0, 0.683, 0.789, 0.858, 0.895, 0.902, 0.897, 0.893, 0.897, 0.896]

steps_absolute = list(np.linspace(0, 600, 10+1))
steps_relative = list(x/6 for x in steps_absolute)

plt.plot(steps_relative, score_f1_ACS, label='least confidence')
plt.plot(steps_relative, score_f1_RS, label='random sampling', linestyle = '--', color = 'lightcoral')
plt.plot(steps_relative, score_f1_EN, label='entropy', linestyle = '-.', color = 'lightgreen')

ymax = max(max(score_f1_ACS),max(score_f1_RS),max(score_f1_EN))
# plt.plot(steps_relative, score_accuracy)
plt.axhline(y=ymax, color='orange', label='no AL')
plt.xlim([0, 100])
plt.ylim([0, 1])
plt.title("BERT based on xiao NER 10% steps")
plt.xlabel('Percentage of manually labeled data')
plt.xticks(list(np.linspace(0, 100, 11)))
plt.ylabel('F1 score')
plt.yticks(list(np.linspace(0, 1, 11)))
plt.legend(loc='lower right')
plt.grid(color='grey', linewidth=0.2)
# plt.ylabel('Accuracy score')
plt.show()

# %% [markdown]
# ### Random sampling - BERT Xiao NER - 10% steps

# %%
# Accumulated results from "\al-nlp-req\NER_from_scratch\Shao_AL_finetune_evalrun"

# starting model:   bert-base-cased
# dataset:          dxiao/requirements-ner
# query strategy:   random sampling
# training time:    ?
# training setup:   10% steps to 600 examples
#                   Num Epochs = 3
#                   Instantaneous batch size per device = 8
#                   Total train batch size (w. parallel, distributed & accumulation) = 8
#                   Gradient Accumulation steps = 1

score_f1 = [0,0.000,0.668,0.803,0.842,0.860,0.882,0.872,0.872,0.898,0.886]
score_accuracy = [0,0.487,0.807,0.910,0.929,0.933,0.932,0.933,0.933,0.940,0.939]

steps_absolute = list(np.linspace(0, 600, 10+1))
steps_relative = list(x/6 for x in steps_absolute)

plt.plot(steps_relative, score_f1, label='random sampling')
# plt.plot(steps_relative, score_accuracy)
plt.axhline(y=max(score_f1), color='orange', label='no AL')
plt.xlim([0, 100])
plt.ylim([0, 1])
plt.title("BERT + NER random sampling based on xiao NER")
plt.xlabel('Percentage of manually labeled data')
plt.xticks(list(np.linspace(0, 100, 11)))
plt.ylabel('F1 score')
plt.yticks(list(np.linspace(0, 1, 11)))
plt.legend(loc='lower right')
plt.grid(color='grey', linewidth=0.2)
# plt.ylabel('Accuracy score')
plt.show()

# %% [markdown]
# ### Random sampling - TAPT Xiao NER (ReqRoBERTa) - 10% steps

# %%
# Accumulated results from "\al-nlp-req\NER_from_scratch\Shao_AL_finetune_evalrun"

# starting model:   limsc/reqroberta-tapt-epoch43
# dataset:          dxiao/requirements-ner
# query strategy:   random sampling
# training time:    ?
# training setup:   10% steps to 600 examples
#                   Num Epochs = 3
#                   Instantaneous batch size per device = 8
#                   Total train batch size (w. parallel, distributed & accumulation) = 8
#                   Gradient Accumulation steps = 1

score_f1 = [0,0.000,0.040,0.187,0.610,0.718,0.768,0.794,0.813,0.825,0.845]
score_accuracy = [0,0.475,0.588,0.688,0.818,0.876,0.892,0.904,0.912,0.916,0.922]

steps_absolute = list(np.linspace(0, 600, 10+1))
steps_relative = list(x/6 for x in steps_absolute)

plt.plot(steps_relative, score_f1, label='random sampling')
# plt.plot(steps_relative, score_accuracy)
plt.axhline(y=max(score_f1), color='orange', label='no AL')
plt.xlim([0, 100])
plt.ylim([0, 1])
plt.title("TAPT + NER random sampling based on xiao NER")
plt.xlabel('Percentage of manually labeled data')
plt.xticks(list(np.linspace(0, 100, 11)))
plt.ylabel('F1 score')
plt.yticks(list(np.linspace(0, 1, 11)))
plt.legend(loc='lower right')
plt.grid(color='grey', linewidth=0.2)
# plt.ylabel('Accuracy score')
plt.show()

# %% [markdown]
# ### Random sampling - TAPT Xiao NER (ReqBERT) - 10% steps - wrong tokenizer

# %%
# Accumulated results from "\al-nlp-req\NER_from_scratch\Shao_AL_finetune_evalrun"

# starting model:   limsc/reqbert-tapt-epoch29
# dataset:          dxiao/requirements-ner
# query strategy:   random sampling
# training time:    ?
# training setup:   10% steps to 600 examples
#                   Num Epochs = 3
#                   Instantaneous batch size per device = 8
#                   Total train batch size (w. parallel, distributed & accumulation) = 8
#                   Gradient Accumulation steps = 1

score_f1 = [0,0.000,0.696,0.821,0.856,0.866,0.876,0.882,0.871,0.880,0.892]
score_accuracy = [0,0.491,0.822,0.917,0.935,0.936,0.938,0.939,0.940,0.942,0.945]

steps_absolute = list(np.linspace(0, 600, 10+1))
steps_relative = list(x/6 for x in steps_absolute)

plt.plot(steps_relative, score_f1, label='random sampling')
# plt.plot(steps_relative, score_accuracy)
plt.axhline(y=max(score_f1), color='orange', label='no AL')
plt.xlim([0, 100])
plt.ylim([0, 1])
plt.title("TAPT + NER random sampling based on xiao NER")
plt.xlabel('Percentage of manually labeled data')
plt.xticks(list(np.linspace(0, 100, 11)))
plt.ylabel('F1 score')
plt.yticks(list(np.linspace(0, 1, 11)))
plt.legend(loc='lower right')
plt.grid(color='grey', linewidth=0.2)
# plt.ylabel('Accuracy score')
plt.show()

# %% [markdown]
# ### Random sampling - TAPT Xiao NER (ReqSciBERT) - 10% steps

# %%
# Accumulated results from "\al-nlp-req\NER_from_scratch\Shao_AL_finetune_evalrun"

# starting model:   limsc/limsc/reqscibert-tapt-epoch20
# dataset:          dxiao/requirements-ner
# query strategy:   random sampling
# training time:    ?
# training setup:   10% steps to 600 examples
#                   Num Epochs = 3
#                   Instantaneous batch size per device = 8
#                   Total train batch size (w. parallel, distributed & accumulation) = 8
#                   Gradient Accumulation steps = 1

score_f1 = [0,0.000,0.272,0.560,0.639,0.756,0.778,0.786,0.804,0.812,0.827]
score_accuracy = [0,0.492,0.686,0.792,0.852,0.882,0.898,0.900,0.904,0.909,0.911]

steps_absolute = list(np.linspace(0, 600, 10+1))
steps_relative = list(x/6 for x in steps_absolute)

plt.plot(steps_relative, score_f1, label='random sampling')
# plt.plot(steps_relative, score_accuracy)
plt.axhline(y=max(score_f1), color='orange', label='no AL')
plt.xlim([0, 100])
plt.ylim([0, 1])
plt.title("TAPT + NER random sampling based on xiao NER")
plt.xlabel('Percentage of manually labeled data')
plt.xticks(list(np.linspace(0, 100, 11)))
plt.ylabel('F1 score')
plt.yticks(list(np.linspace(0, 1, 11)))
plt.legend(loc='lower right')
plt.grid(color='grey', linewidth=0.2)
# plt.ylabel('Accuracy score')
plt.show()

# %% [markdown]
# ### Random sampling - TAPT Xiao NER (ReqRoBERTa) - 10% steps

# %%
# Accumulated results from "\al-nlp-req\NER_from_scratch\Shao_AL_finetune_evalrun"

# starting model:   limsc/reqroberta-tapt-epoch43
# dataset:          dxiao/requirements-ner
# query strategy:   random sampling
# training time:    ?
# training setup:   10% steps to 600 examples
#                   Num Epochs = 3
#                   Instantaneous batch size per device = 8
#                   Total train batch size (w. parallel, distributed & accumulation) = 8
#                   Gradient Accumulation steps = 1

score_f1 = [0,0.000,0.613,0.834,0.879,0.882,0.890,0.888,0.893,0.897,0.898]
score_accuracy = [0,0.478,0.796,0.927,0.939,0.935,0.938,0.940,0.939,0.942,0.943]

#wrong tokenizer
# score_f1 = [0,0.000,0.040,0.187,0.610,0.718,0.768,0.794,0.813,0.825,0.845]
# score_accuracy = [0,0.475,0.588,0.688,0.818,0.876,0.892,0.904,0.912,0.916,0.922]

steps_absolute = list(np.linspace(0, 600, 10+1))
steps_relative = list(x/6 for x in steps_absolute)

plt.plot(steps_relative, score_f1, label='random sampling')
# plt.plot(steps_relative, score_accuracy)
plt.axhline(y=max(score_f1), color='orange', label='no AL')
plt.xlim([0, 100])
plt.ylim([0, 1])
plt.title("TAPT (ReqRoBERTa) + NER random sampling based on xiao NER")
plt.xlabel('Percentage of manually labeled data')
plt.xticks(list(np.linspace(0, 100, 11)))
plt.ylabel('F1 score')
plt.yticks(list(np.linspace(0, 1, 11)))
plt.legend(loc='lower right')
plt.grid(color='grey', linewidth=0.2)
# plt.ylabel('Accuracy score')
plt.show()

# %% [markdown]
# ### Random sampling - TAPT Shao NER (ReqRoBERTa)- 10% steps

# %%
# Accumulated results from "\al-nlp-req\NER_from_scratch\Shao_AL_finetune_evalrun"

# starting model:   limsc/reqroberta-tapt-epoch43
# dataset:          limsc/requirements-entity-recognition
# query strategy:   random sampling
# training time:    ?
# training setup:   10% steps to 600 examples
#                   Num Epochs = 3
#                   Instantaneous batch size per device = 8
#                   Total train batch size (w. parallel, distributed & accumulation) = 8
#                   Gradient Accumulation steps = 1

score_f1 = [0,0.000,0.736,0.831,0.884,0.904,0.902,0.911,0.919,0.917,0.924]
score_accuracy = [0,0.588,0.856,0.937,0.952,0.955,0.959,0.961,0.963,0.966,0.966]


# wrong tokenizer
# score_f1 = [0,0.000,0.023,0.377,0.592,0.720,0.787,0.812,0.834,0.836,0.856]
# score_accuracy = [0,0.588,0.594,0.740,0.820,0.880,0.906,0.914,0.925,0.925,0.935]

steps_absolute = list(np.linspace(0, 600, 10+1))
steps_relative = list(x/6 for x in steps_absolute)

plt.plot(steps_relative, score_f1, label='random sampling')
# plt.plot(steps_relative, score_accuracy)
plt.axhline(y=max(score_f1), color='orange', label='no AL')
plt.xlim([0, 100])
plt.ylim([0, 1])
plt.title("TAPT (ReqRoBERTa) + NER random sampling based on shao NER")
plt.xlabel('Percentage of manually labeled data')
plt.xticks(list(np.linspace(0, 100, 11)))
plt.ylabel('F1 score')
plt.yticks(list(np.linspace(0, 1, 11)))
plt.legend(loc='lower right')
plt.grid(color='grey', linewidth=0.2)
# plt.ylabel('Accuracy score')
plt.show()

# %% [markdown]
# ### Random sampling - Shao NER - 10% steps

# %%
# Accumulated results from "\al-nlp-req\NER_from_scratch\AL_finetune_evalrun"

# starting model:   bert-base-cased
# dataset:          limsc/requirements-entity-recognition
# query strategy:   random sampling
# training time:    ?
# training setup:   10% steps to 600 examples
#                   Num Epochs = 3
#                   Instantaneous batch size per device = 8
#                   Total train batch size (w. parallel, distributed & accumulation) = 8
#                   Gradient Accumulation steps = 1

# %%
score_f1 = [0,0.059,0.733,0.842,0.871,0.884,0.892,0.891,0.900,0.907,0.905]
score_accuracy = [0,0.598,0.854,0.929,0.947,0.949,0.953,0.952,0.957,0.960,0.958]

steps_absolute = list(np.linspace(0, 600, 10+1))
steps_relative = list(x/6 for x in steps_absolute)

plt.plot(steps_relative, score_f1, label='random sampling')
# plt.plot(steps_relative, score_accuracy)
plt.axhline(y=0.907, color='orange', label='no AL')
plt.xlim([0, 100])
plt.ylim([0, 1])
plt.title("BERT + NER random sampling based on shao NER")
plt.xlabel('Percentage of manually labeled data')
plt.xticks(list(np.linspace(0, 100, 11)))
plt.ylabel('F1 score')
plt.yticks(list(np.linspace(0, 1, 11)))
plt.legend()
plt.grid(color='grey', linewidth=0.2)
# plt.ylabel('Accuracy score')
plt.show()

# %% [markdown]
# ### Random sampling from scratch - conll2003 - 5% steps

# %%
# Accumulated results from "\al-nlp-req\NER_from_scratch\AL_finetune_evalrun"

# starting model:   bert-base-cased
# dataset:          conll2003 (reduced to 10000/3250/3453)
# query strategy:   random sampling
# training time:    ?
# training setup:   5% steps to 7500 examples
#                   Num Epochs = 3
#                   Instantaneous batch size per device = 8
#                   Total train batch size (w. parallel, distributed & accumulation) = 8
#                   Gradient Accumulation steps = 1

# %%
score_f1 = [0, 0.644,0.866,0.873,0.880,0.891,0.904,0.907,0.911,0.911,0.910,0.918,0.906,0.917,0.916,0.912, 0.912, 0.912, 0.912,0.912,0.912]
score_accuracy = [0,0.928,0.970,0.971,0.973,0.975,0.978,0.979,0.979,0.979,0.979,0.980,0.978,0.980,0.980,0.979,0.979,0.979,0.979,0.979,0.979]

steps_absolute = list(np.linspace(0, 10000, 21))
steps_relative = list(x/100 for x in steps_absolute)

plt.plot(steps_relative, score_f1, label='random sampling')
# plt.plot(steps_relative, score_accuracy)
plt.axhline(y=0.920, color='orange', label='no AL')
plt.xlim([0, 100])
plt.ylim([0, 1])
plt.title("NER random sampling based on conll2003")
plt.xlabel('Percentage of manually labeled data')
plt.xticks(list(np.linspace(0, 100, 11)))
plt.ylabel('F1 score')
plt.yticks(list(np.linspace(0, 1, 11)))
plt.legend()
plt.legend(loc='lower right')
plt.grid(color='grey', linewidth=0.2)
# plt.ylabel('Accuracy score')
plt.show()

# %% [markdown]
# ### Random sampling from scratch - conll2003 - 10% steps

# %%
# Accumulated results from "\al-nlp-req\NER_from_scratch\AL_finetune_evalrun"

# starting model:   bert-base-cased
# dataset:          conll2003 (reduced to 10000/3250/3453)
# query strategy:   random sampling
# training time:    ?
# training setup:   10% steps to 10000 examples
#                   Num Epochs = 3
#                   Instantaneous batch size per device = 8
#                   Total train batch size (w. parallel, distributed & accumulation) = 8
#                   Gradient Accumulation steps = 1

# %%
score_f1 = [0, 0.825, 0.876, 0.883, 0.903, 0.904, 0.908, 0.913, 0.912, 0.913, 0.916]
score_accuracy = [0, 0.969, 0.975, 0.977, 0.979, 0.980, 0.981, 0.981, 0.982, 0.982, 0.983]

# score_f1 = [0, 0.777, 0.864, 0.890, 0.912, 0.917, 0.918, 0.924, 0.929, 0.928, 0.936] # validation set results
# score_accuracy = [0, 0.954, 0.970, 0.974, 0.977, 0.980, 0.980, 0.981, 0.983, 0.983, 0.984] # validation set results
steps_absolute = list(np.linspace(0, 10000, 11))
steps_relative = list(x/100 for x in steps_absolute)

plt.plot(steps_relative, score_f1, label='random sampling')
# plt.plot(steps_relative, score_accuracy)
plt.axhline(y=0.920, color='orange', label='no AL')
plt.xlim([0, 100])
plt.ylim([0, 1])
plt.title("NER random sampling based on conll2003")
plt.xlabel('Percentage of manually labeled data')
plt.xticks(list(np.linspace(0, 100, 11)))
plt.ylabel('F1 score')
plt.yticks(list(np.linspace(0, 1, 11)))
plt.legend()
plt.legend(loc='lower right')
plt.grid(color='grey', linewidth=0.2)
# plt.ylabel('Accuracy score')
plt.show()

# %% [markdown]
# ### Multi-class small-text example

# %%
# Accumulated results from "\small-text\examples\examplecode\transformers_multiclass_classification"

# starting model:   distilroberta-base
# dataset:          20newsgroups (full 210? ?/?/?)
# query strategy:   prediction entropy
# training time:    17 min
# training setup:   10% steps starting at ~15% (30/210) init
#                   Num Epochs = 10
#                   Instantaneous batch size per device = ?
#                   Total train batch size (w. parallel, distributed & accumulation) = ?
#                   Gradient Accumulation steps = ?

# %%
train_accuracy = [0.63, 0.42, 0.77, 0.73, 0.81, 0.82, 0.76, 0.84, 0,86, 0.85]
test_accuracy = [0.33, 0.34, 0.62, 0.62, 0.90, 0.93, 0.88, 0.94, 0.93, 0.93]
steps_absolute = [30, 50, 70, 90, 110, 130, 150, 170, 190, 210]
steps_relative = list(str(int(x/210*100)) + "%" for x in steps_absolute)

plt.plot(steps_relative, test_accuracy)
# plt.plot(label_iteration, train_accuracy)
plt.title("small-text multiclass classification on 20newsgroups dataset")
plt.xlabel('percentage of manually labeled data')
plt.ylabel('test accuracy')
plt.grid(color='grey', linewidth=0.2)
plt.show()

# %% [markdown]
# ### Multi-label small-text example

# %%
# Accumulated results from "\al-nlp-req\small-text\small-text_example2"

# starting model:   distilroberta-base
# dataset:          go-emotions (reduced to 10000/1000/1000)
# query strategy:   prediction entropy
# training time:    1:50h
# training setup:   5% steps to 6000/10000 examples starting at 15% init
#                   Num Epochs = ?
#                   Instantaneous batch size per device = ?
#                   Total train batch size (w. parallel, distributed & accumulation) = ?
#                   Gradient Accumulation steps = ?

# %%
train_accuracy = [0.39, 0.36, 0.51, 0.59, 0.56, 0.63, 0.63, 0.59, 0.68, 0.73]
test_accuracy = [0.30, 0.32, 0.42, 0.48, 0.49, 0.50, 0.52, 0.51, 0.52, 0.54]
steps_absolute = [1500, 2000, 2500, 3000, 3500, 4000, 4500, 5000, 5500, 6000]
steps_relative = list(map(lambda x: str(int(x/100)) + "%", steps_absolute))

plt.plot(steps_relative, test_accuracy)
# plt.plot(label_iteration, train_accuracy)
plt.title("small-text multilabel classification on go-emotion dataset")
plt.xlabel('percentage of manually labeled data')
plt.ylabel('test accuracy')
plt.grid(color='grey', linewidth=0.2)
plt.show()

# %% [markdown]
# ### Incose paper, LC 2% Xiao NER

# %%
import matplotlib.pyplot as plt
plt.rcParams["font.family"] = "serif"
plt.rcParams["font.serif"] = ["Times New Roman"]
plt.rcParams.update({'font.size': 12})

# shuffled (seed 42)
score_f1_ACS = [0,0.002,0.000,0.192,0.472,0.656,0.760,0.783,0.813,0.823,0.845,0.846,0.866,0.879,0.883,0.881,0.883,0.892,0.890,0.888,0.886,0.880,0.888,0.886,0.883,0.888,0.887,0.887,0.888,0.893,0.888,0.881,0.883,0.891,0.890,0.891,0.892,0.894,0.894,0.895,0.893,0.898,0.896,0.890,0.893,0.893,0.891,0.888,0.889,0.886,0.884]

steps_absolute = list(np.linspace(0, 600, 50+1))
steps_relative = list(x/6 for x in steps_absolute)
plt.plot(steps_relative, score_f1_ACS, color = 'grey', label='with Active Learning')

ymax = max(score_f1_ACS)
plt.axhline(y=ymax, color='black', label='without Active Learning')
plt.xlim([0, 100])
plt.ylim([0, 1])
plt.title("Learning curves for labeling entities in requirement sentences")
plt.xlabel('Percentage of manually labeled data')
plt.xticks(list(np.linspace(0, 100, 11)))
plt.ylabel('F1 score')
plt.yticks(list(np.linspace(0, 1, 11)))
plt.legend(loc='lower right')
plt.grid(color='grey', linewidth=0.2)
# plt.ylabel('Accuracy score')
plt.show()
